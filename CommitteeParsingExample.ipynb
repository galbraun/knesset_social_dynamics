# %% [markdown]
# # Imports

# %%
from knesset_social_dynamics.parsers import commitees
import pathlib
import random

# %% [markdown]
# # Choose a random committee file from the folder

# %%
committees_protocols_folder =  pathlib.Path('data/committee_protocols/')

# %%
random_committee_proto_path = random.choice(list(committees_protocols_folder.glob("*.doc")))

# %% [markdown]
# # Extract committee transcript

# %%
transcript = commitees.extract_committee_new_transcript(random_committee_proto_path)
# Out:
# 2020-07-10 11:14:26.286 | DEBUG    | knesset_social_dynamics.parsers.text_extractor:extract_new_raw_protocol:15 - Parsing new-version protocoal

# %%
transcript
# Out:
#    interaction       speaker_name            speaker_party  \
# 0   << דובר >>       אבי ניסנקורן  יושב- ראש הוועדה המסדרת
# 1   << דובר >>       אבי ניסנקורן  יושב- ראש הוועדה המסדרת
# 2   << דובר >>       אבי ניסנקורן  יושב- ראש הוועדה המסדרת
# 3   << דובר >>       אבי ניסנקורן  יושב- ראש הוועדה המסדרת
# 4   << דובר >>       אבי ניסנקורן  יושב- ראש הוועדה המסדרת
# 5   << דובר >>       אבי ניסנקורן  יושב- ראש הוועדה המסדרת
# 6   << דובר >>       אבי ניסנקורן                 כחול לבן
# 7    << יור >>  עאידה תומא סלימאן                     יו"ר
# 8   << דובר >>  מיכאל מרדכי ביטון                 כחול לבן
# 9    << יור >>  עאידה תומא סלימאן                     יו"ר
# 10  << דובר >>          אחמד טיבי           הרשימה המשותפת
# 11   << יור >>  עאידה תומא סלימאן                     יו"ר
# 12  << דובר >>         אלון שוסטר                 כחול לבן
# 13  << דובר >>         איימן עודה           הרשימה המשותפת
# 14  << דובר >>         אלון שוסטר                 כחול לבן
# 15   << יור >>  עאידה תומא סלימאן                     יו"ר
# 16  << דובר >>        סונדוס סלאח           הרשימה המשותפת
# 17   << יור >>  עאידה תומא סלימאן                     יו"ר
# 18  << דובר >>    בועז טופורובסקי                 כחול לבן
# 19  << דובר >>             רם שפע                 כחול לבן
# 20  << דובר >>         איימן עודה           הרשימה המשותפת
# 21  << דובר >>         איימן עודה           הרשימה המשותפת
# 22   << יור >>  עאידה תומא סלימאן                     יו"ר
# 23   << יור >>  עאידה תומא סלימאן                     יו"ר
#
#                   subject                                               text
# 0    בחירת יושב ראש ועדה   אנחנו פותחים את הישיבה הראשונה של הוועדה המיוח...
# 1    בחירת יושב ראש ועדה                                               הצבעה
# 2    בחירת יושב ראש ועדה                                             בעד – 7
# 3    בחירת יושב ראש ועדה                                           נגד – אין
# 4    בחירת יושב ראש ועדה                                        נמנעים – אין
# 5    בחירת יושב ראש ועדה                                        ההצעה נתקבלה
# 6    בחירת יושב ראש ועדה   המינוי אושר פה-אחד, ברכות לחברת הכנסת תומא סלי...
# 7    בחירת יושב ראש ועדה   תודה. אני רוצה להודות לך, חבר הכנסת ניסנקורן. ...
# 8    בחירת יושב ראש ועדה   אני מחליף את מירב כהן שהיא חברת ועדה. חברת הכנ...
# 9    בחירת יושב ראש ועדה   תודה. כבר ביום שני הקרוב נתחיל בעבודה. מיד תקב...
# 10   בחירת יושב ראש ועדה   גבירתי היושבת-ראש, זה רגע משמח בגלל חשיבות התפ...
# 11   בחירת יושב ראש ועדה                                              תודה.
# 12   בחירת יושב ראש ועדה   אני רוצה לברך את כולנו שהחיינו וקיימנו והגענו ...
# 13   בחירת יושב ראש ועדה                         עוד מעט רצים לרשות הממשלה.
# 14   בחירת יושב ראש ועדה   יש לנו משבר כלכלי קשה, משבר חוקתי קשה, והעדות ...
# 15   בחירת יושב ראש ועדה   תודה לחבר הכנסת שוסטר. ריגשת אותי בדבריך כאן ו...
# 16   בחירת יושב ראש ועדה   \tאני רוצה לברך את חברתי, חברת הכנסת המדהימה, ...
# 17   בחירת יושב ראש ועדה                    תודה. חבר הכנסת בועז טופורובסקי.
# 18   בחירת יושב ראש ועדה   גם אני מצטרף לברכות, זו ועדה חשובה מאוד, המון ...
# 19   בחירת יושב ראש ועדה   שמח מאוד להיות פה. סוריאליסטי ועצוב שרק אנחנו ...
# 20   בחירת יושב ראש ועדה   מברוק עאידה. את נמצאת פה בזכות וברגע הנכון. יש...
# 21   בחירת יושב ראש ועדה   לפני שעה קלה הייתי בוועדה למאבק בפשיעה בקרב הא...
# 22   בחירת יושב ראש ועדה   שוקרן כתיר, תודה לכולכם. חבל שלא כל חברי הוועד...
# 23   בחירת יושב ראש ועדה   כבר היום התחילו לצאת מכתבים למשרדים בנושאים הש...
